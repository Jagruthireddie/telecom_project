# %% [markdown]
# <a href="https://colab.research.google.com/github/Jagruthireddie/telecom_project/blob/main/app_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import streamlit as st
import pickle
import numpy as np
import pandas as pd

st.title("Telco Customer Churn Prediction")

model = pickle.load(open("model.pkl", "rb"))
scaler = pickle.load(open("scaler.pkl", "rb"))
columns = pickle.load(open("columns.pkl", "rb"))

tenure = st.number_input("Tenure", 0, 72, 12)
monthly = st.number_input("Monthly Charges", 0.0, 200.0, 70.0)

input_df = pd.DataFrame(np.zeros((1, len(columns))), columns=columns)
input_df["tenure"] = tenure
input_df["MonthlyCharges"] = monthly

input_scaled = scaler.transform(input_df)

if st.button("Predict"):
    result = model.predict(input_scaled)[0]
    if result == 1:
        st.error("Customer likely to CHURN")
    else:
        st.success("Customer likely to STAY")
